# %%
# https://www.kaggle.com/code/sitrakamatthew/topanime-eda

# %% [markdown]
# # Bronze Medal :D

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp310-cp310-win_amd64.whl (153 kB)
#      -------------------------------------- 153.1/153.1 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\sitra\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wordcloud) (3.6.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\sitra\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wordcloud) (1.23.2)
# Requirement already satisfied: pillow in c:\users\sitra\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sitra\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sitra\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->wordcloud) (2.8.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sitra\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->wordcloud) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sitra\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sitra\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sitra\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\sitra\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\sitra\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\sitra\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# git clone https://github.com/amueller/word_cloud.git

# %%
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = "square"

x, y = np.ogrid[:300, :300]

mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
mask = 255 * mask.astype(int)


wc = WordCloud(background_color="white", repeat=True, mask=mask)
wc.generate(text)

plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.show()

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud

# %%
TXT_FILE = C:\Users\sitra\OneDrive\Documents\Data\Learning-Data-Science\Goodies\fun_and_pro

# %%
file_path = r"C:\Users\sitra\OneDrive\Documents\Data\Learning-Data-Science\Goodies\fun_and_pro\Camus.txt"

with open(file_path, 'r') as file:
    contents = file.read()

# %%
# Read text
text = open(contents, mode="r", encoding="utf-8").read()
stopwords = STOPWORDS

wc = WordCloud(background_color="white", stopwords=stopwords, height=600, width=400)
wc.generate(text)

# store to file
wc.to_file("wordcloud_output.png")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\sitra\OneDrive\Documents\Data\Kaggle\Notebooks\top_anime.ipynb Cell 9 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/sitra/OneDrive/Documents/Data/Kaggle/Notebooks/top_anime.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # Read text
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sitra/OneDrive/Documents/Data/Kaggle/Notebooks/top_anime.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> text = open(contents, mode="r", encoding="utf-8").read()
#       <a href='vscode-notebook-cell:/c%3A/Users/sitra/OneDrive/Documents/Data/Kaggle/Notebooks/top_anime.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> stopwords = STOPWORDS
#       <a href='vscode-notebook-cell:/c%3A/Users/sitra/OneDrive/Documents/Data/Kaggle/Notebooks/top_anime.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> wc = WordCloud(background_color="white", stopwords=stopwords, height=600, width=400)
#
# OSError: [Errno 22] Invalid argument: 'Sire, Madame, Altesses Royales, Mesdames, Messieurs,\n\nEn recevant la distinction dont votre libre AcadÃ©mie a bien voulu mâ€™honorer, ma gratitude Ã©tait dâ€™autant plus profonde que je mesurais Ã\xa0 quel point cette rÃ©compense dÃ©passait mes mÃ©rites personnels. Tout homme et, Ã\xa0 plus forte raison, tout artiste, dÃ©sire Ãªtre reconnu. Je le dÃ©sire aussi. Mais il ne mâ€™a pas Ã©tÃ© possible dâ€™apprendre votre dÃ©cision sans comparer son retentissement Ã\xa0 ce que je suis rÃ©ellement. Comment un homme presque jeune, riche de ses seuls doutes et dâ€™une Å“uvre encore en chantier, habituÃ© Ã\xa0 vivre dans la solitude du travail ou dans les retraites de lâ€™amitiÃ©, nâ€™aurait-il pas appris avec une sorte de panique un arrÃªt qui le portait dâ€™un coup, seul et rÃ©duit Ã\xa0 lui-mÃªme, au centre dâ€™une lumiÃ¨re crue ? De quel cÅ“ur aussi pouvait-il recevoir cet honneur Ã\xa0 lâ€™heure oÃ¹, en Europe, dâ€™autres Ã©crivains, parmi les plus grands, sont rÃ©duits au silence, et dans le temps mÃªme oÃ¹ sa terre natale connaÃ®t un malheur incessant ?\n\nJâ€™ai connu ce dÃ©sarroi et ce trouble intÃ©rieur. Pour retrouver la paix, il mâ€™a fallu, en somme, me mettre en rÃ¨gle avec un sort trop gÃ©nÃ©reux. Et, puisque je ne pouvais mâ€™Ã©galer Ã\xa0 lui en mâ€™appuyant sur mes seuls mÃ©rites, je nâ€™ai rien trouvÃ© dâ€™autre pour mâ€™aider que ce qui mâ€™a soutenu tout au long de ma vie, et dans les circonstances les plus contraires : lâ€™idÃ©e que je me fais de mon art et du rÃ´le de lâ€™Ã©crivain. Permettez seulement que, dans un sentiment de reconnaissance et dâ€™amitiÃ©, je vous dise, aussi simplement que je le pourrai, quelle est cette idÃ©e.\n\nJe ne puis vivre personnellement sans mon art. Mais je nâ€™ai jamais placÃ© cet art au-dessus de tout. Sâ€™il mâ€™est nÃ©cessaire au contraire, câ€™est quâ€™il ne se sÃ©pare de personne et me permet de vivre, tel que je suis, au niveau de tous. Lâ€™art nâ€™est pas Ã\xa0 mes yeux une rÃ©jouissance solitaire. Il est un moyen dâ€™Ã©mouvoir le plus grand nombre dâ€™hommes en leur offrant une image privilÃ©giÃ©e des souffrances et des joies communes. Il oblige donc lâ€™artiste Ã\xa0 ne pas se sÃ©parer ; il le soumet Ã\xa0 la vÃ©ritÃ© la plus humble et la plus universelle. Et celui qui, souvent, a choisi son destin dâ€™artiste parce quâ€™il se sentait diffÃ©rent apprend bien vite quâ€™il ne nourrira son art, et sa diffÃ©rence, quâ€™en avouant sa ressemblance avec tous. Lâ€™artiste se forge dans cet aller retour perpÃ©tuel de lui aux autres, Ã\xa0 mi-chemin de la beautÃ© dont il ne peut se passer et de la communautÃ© Ã\xa0 laquelle il ne peut sâ€™arracher. Câ€™est pourquoi les vrais artistes ne mÃ©prisent rien ; ils sâ€™obligent Ã\xa0 comprendre au lieu de juger. Et sâ€™ils ont un parti Ã\xa0 prendre en ce monde ce ne peut Ãªtre que celui dâ€™une sociÃ©tÃ© oÃ¹, selon le grand mot de Nietzsche, ne rÃ¨gnera plus le juge, mais le crÃ©ateur, quâ€™il soit travailleur ou intellectuel.\n\nLe rÃ´le de lâ€™Ã©crivain, du mÃªme coup, ne se sÃ©pare pas de devoirs difficiles. Par dÃ©finition, il ne peut se mettre aujourdâ€™hui au service de ceux qui font lâ€™histoire : il est au service de ceux qui la subissent. Ou sinon, le voici seul et privÃ© de son art. Toutes les armÃ©es de la tyrannie avec leurs millions dâ€™hommes ne lâ€™enlÃ¨veront pas Ã\xa0 la solitude, mÃªme et surtout sâ€™il consent Ã\xa0 prendre leur pas. Mais le silence dâ€™un prisonnier inconnu, abandonnÃ© aux humiliations Ã\xa0 lâ€™autre bout du monde, suffit Ã\xa0 retirer lâ€™Ã©crivain de lâ€™exil chaque fois, du moins, quâ€™il parvient, au milieu des privilÃ¨ges de la libertÃ©, Ã\xa0 ne pas oublier ce silence, et Ã\xa0 le relayer pour le faire retentir par les moyens de lâ€™art.\n\nAucun de nous nâ€™est assez grand pour une pareille vocation. Mais dans toutes les circonstances de sa vie, obscur ou provisoirement cÃ©lÃ¨bre, jetÃ© dans les fers de la tyrannie ou libre pour un temps de sâ€™exprimer,  ...

# %%
import os
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Set the file path
file_path = r"C:\Users\sitra\OneDrive\Documents\Data\Learning-Data-Science\Goodies\fun_and_pro\Camus.txt"

# Read in the file contents
with open(file_path, 'r') as file:
    text = file.read()

# Create a WordCloud object and generate the word cloud
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(text)

# Display the word cloud
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
import os
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Set the file path
file_path = r"C:\Users\sitra\OneDrive\Documents\Data\Learning-Data-Science\Goodies\fun_and_pro\Camus.txt"

# Read in the file contents
with open(file_path, 'r') as file:
    text = file.read()

# Create a WordCloud object with stop words removed and generate the word cloud
stopwords = set(STOPWORDS)
wordcloud = WordCloud(width=800, height=800, background_color='white', stopwords=stopwords, min_font_size=10).generate(text)

# Display the word cloud
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
import os
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Set the file path
file_path = r"C:\Users\sitra\OneDrive\Documents\Data\Learning-Data-Science\Goodies\fun_and_pro\Bezzos.txt"

# Read in the file contents
with open(file_path, 'r') as file:
    text = file.read()

# Create a WordCloud object with stop words removed and generate the word cloud
stopwords = set(STOPWORDS)
wordcloud = WordCloud(width=800, height=800, background_color='white', stopwords=stopwords, min_font_size=10).generate(text)

# Display the word cloud
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\sitra\OneDrive\Documents\Data\Kaggle\Notebooks\top_anime.ipynb Cell 12 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/sitra/OneDrive/Documents/Data/Kaggle/Notebooks/top_anime.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a> # Read in the file contents
#       <a href='vscode-notebook-cell:/c%3A/Users/sitra/OneDrive/Documents/Data/Kaggle/Notebooks/top_anime.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a> with open(file_path, 'r') as file:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sitra/OneDrive/Documents/Data/Kaggle/Notebooks/top_anime.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a>     text = file.read()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 217: character maps to <undefined>
